# %%
#El módulo glob facilita la búsqueda de todas las rutas y ficheros que coinciden con un patrón específico
#aunque los resultados se devuelven en un orden arbitrario
import glob

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\IMPORTSOLUTION\\Desktop\\DEBERES_PYTHON\\python-novice-gapminder-data (1)\\data'

# %%
import csv

# %%
for fichero in glob.glob('c:\\Users\\IMPORTSOLUTION\\Desktop\\DEBERES_PYTHON'):
    print(fichero)
# Out:
# c:\Users\IMPORTSOLUTION\Desktop\DEBERES_PYTHON

# %%
import pandas as pd
import numpy as np

# %%
glob.glob('*')
# Out:
# ['gapminder_all.csv',
#  'gapminder_gdp_africa.csv',
#  'gapminder_gdp_americas.csv',
#  'gapminder_gdp_asia.csv',
#  'gapminder_gdp_europe.csv',
#  'gapminder_gdp_oceania.csv',
#  'Practica 4-10-2023 glob_os_oppend_makedirs.ipynb']

# %%
glob.glob("python-novice-gapminder-data(1)/data/*.csv")
# Out:
# []

# %%
glob.glob("python-novice-gapminder-data (1)/data/*.csv")
# Out:
# ['python-novice-gapminder-data (1)/data\\gapminder_all.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_africa.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_americas.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_asia.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_europe.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_oceania.csv']

# %%
archivos_pib = glob.glob("python-novice-gapminder-data (1)/data/*.csv")
archivos_pib
# Out:
# ['python-novice-gapminder-data (1)/data\\gapminder_all.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_africa.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_americas.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_asia.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_europe.csv',
#  'python-novice-gapminder-data (1)/data\\gapminder_gdp_oceania.csv']

# %%
pd.read_csv(archivos_pib[0])
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...

# %%
for archivo in archivos_pib:
    datos = pd.read_csv(archivo)

# %%
pib_africa = pd.read_csv(archivos_pib[0])
pib_africa
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...

# %%
pib_Asia = pd.read_csv(archivos_pib[3])
pib_Asia
# Out:
#                country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0          Afghanistan      779.445314      820.853030      853.100710
# 1              Bahrain     9867.084765    11635.799450    12753.275140
# 2           Bangladesh      684.244172      661.637458      686.341554
# 3             Cambodia      368.469286      434.038336      496.913648
# 4                China      400.448611      575.987001      487.674018
# 5      Hong Kong China     3054.421209     3629.076457     4692.648272
# 6                India      546.565749      590.061996      658.347151
# 7            Indonesia      749.681655      858.900271      849.289770
# 8                 Iran     3035.326002     3290.257643     4187.329802
# 9                 Iraq     4129.766056     6229.333562     8341.737815
# 10              Israel     4086.522128     5385.278451     7105.630706
# 11               Japan     3216.956347     4317.694365     6576.649461
# ...

# %%
pd.concat([pib_africa,pib_Asia])
# Out:
#    continent             country  gdpPercap_1952  gdpPercap_1957  \
# 0     Africa             Algeria     2449.008185     3013.976023
# 1     Africa              Angola     3520.610273     3827.940465
# 2     Africa               Benin     1062.752200      959.601080
# 3     Africa            Botswana      851.241141      918.232535
# 4     Africa        Burkina Faso      543.255241      617.183465
# ..       ...                 ...             ...             ...
# 28       NaN              Taiwan     1206.947913     1507.861290
# 29       NaN            Thailand      757.797418      793.577415
# 30       NaN             Vietnam      605.066492      676.285448
# 31       NaN  West Bank and Gaza     1515.592329     1827.067742
# 32       NaN          Yemen Rep.      781.717576      804.830455
#
#     gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# 0      2550.816880     3246.991771     4182.663766     4910.416756
# ...

# %%
pib_africa.shape[0]
# Out:
# 142

# %%
pib_Asia.shape[0]
# Out:
# 33
