# %%
mi_dicccionario = {'nombre':'Carolina',
                   'edad': 30,
                    'licencia': True,
                     'deportes':['correr','bicicleta']}
mi_dicccionario
# Out:
# {'nombre': 'Carolina',
#  'edad': 30,
#  'licencia': True,
#  'deportes': ['correr', 'bicicleta']}

# %%
mi_dicccionario2 = dict(nombre = 'Carolina',
                        edad = '30',
                        licencia = 'True')
mi_dicccionario2
# Out:
# {'nombre': 'Carolina', 'edad': '30', 'licencia': 'True'}

# %%
mi_dicccionario['nombre']
# Out:
# 'Carolina'

# %%
mi_dicccionario.get('nombre')
# Out:
# 'Carolina'

# %%
mi_dicccionario.keys()
# Out:
# dict_keys(['nombre', 'edad', 'licencia', 'deportes'])

# %%
mi_dicccionario.values()
# Out:
# dict_values(['Carolina', 30, True, ['correr', 'bicicleta']])

# %%
mi_dicccionario['edad'] = 30
mi_dicccionario
# Out:
# {'nombre': 'Carolina',
#  'edad': 30,
#  'licencia': True,
#  'deportes': ['correr', 'bicicleta']}

# %%
mi_dicccionario['eduacaion'] = 'universidad'
mi_dicccionario
# Out:
# {'nombre': 'Carolina',
#  'edad': 30,
#  'licencia': True,
#  'deportes': ['correr', 'bicicleta'],
#  'eduacaion': 'universidad'}

# %%
for llave in mi_dicccionario.values():
    print(llave)
# Out:
# Carolina
# 30
# True
# ['correr', 'bicicleta']
# universidad

# %%
# Dostipos de bucles for, if
for llave in mi_dicccionario:
    if llave == 'edad':
       print(llave, mi_dicccionario[llave])
# Out:
# edad 30

# %%
#se utlizo el comando pop
mi_dicccionario.pop('edad')
# Out:
# 30

# %%
# Dostipos de bucles for, if
for llave in mi_dicccionario:
    if llave == 'nombre':
       print(llave, mi_dicccionario[llave])
# Out:
# nombre Carolina

# %%
# Dostipos de bucles for, if
for llave in mi_dicccionario:
    if llave == 'deportes':
       print(llave, mi_dicccionario[llave])
# Out:
# deportes ['correr', 'bicicleta']

# %%
for llave in mi_dicccionario:
    print(mi_dicccionario[llave])
# Out:
# Carolina
# True
# ['correr', 'bicicleta']
# universidad

# %%
mi_dicccionario
# Out:
# {'nombre': 'Carolina',
#  'licencia': True,
#  'deportes': ['correr', 'bicicleta'],
#  'eduacaion': 'universidad'}

# %%
mi_dicccionario2 = dict(nombre1 = 'Carolina',
                    edad = 30,
                    licencia = True,
                    nombre2 = 'Jairo')
mi_dicccionario2
# Out:
# {'nombre1': 'Carolina', 'edad': 30, 'licencia': True, 'nombre2': 'Jairo'}

# %%
clase ={'estudiante1':{'nombre':'Carolina','edad':'30'},
        'estudiante2' :{'nombre':'Jairo', 'edad': '33'}}

# %%
clase
# Out:
# {'estudiante1': {'nombre': 'Carolina', 'edad': '30'},
#  'estudiante2': {'nombre': 'Jairo', 'edad': '33'}}

# %%
clase['estudiante1']['nombre']
# Out:
# 'Carolina'

# %%
clase['estudiante2']['nombre']
# Out:
# 'Jairo'

# %%
import pandas as pd

# %%
#Los corchetes defienen una lista
{'nombres':['Carolina','Jairo','Jefferson'],
 'edades':[30,33,36]}
# Out:
# {'nombres': ['Carolina', 'Jairo', 'Jefferson'], 'edades': [30, 33, 36]}

# %%
# Realizar un DataFrame
pd.DataFrame({'nombres':['Carolina','Jairo','Jefferson'],
              'edades':['30','33','36']})
# Out:
#      nombres edades
# 0   Carolina     30
# 1      Jairo     33
# 2  Jefferson     36

# %%
#con mi dicccionario
midic = {'nombres':['Carolina','Jairo','Jefferson'],
              'edades':['30','33','36']}
midic
# Out:
# {'nombres': ['Carolina', 'Jairo', 'Jefferson'], 'edades': ['30', '33', '36']}

# %%
pd.DataFrame(midic)
# Out:
#      nombres edades
# 0   Carolina     30
# 1      Jairo     33
# 2  Jefferson     36

# %%
midic ['educacion'] = {'Diplomado','Posgrado','Universidad'}
midic
# Out:
# {'nombres': ['Carolina', 'Jairo', 'Jefferson'],
#  'edades': ['30', '33', '36'],
#  'educacion': {'Diplomado', 'Posgrado', 'Universidad'}}

# %%
midic
# Out:
# {'nombres': ['Carolina', 'Jairo', 'Jefferson'],
#  'edades': ['30', '33', '36'],
#  'educacion': {'Diplomado', 'Posgrado', 'Universidad'}}

# %%
import numpy as np

# %%
# ponen en nulo es np.nan
midic['educacion']= ['Diplomado','Posgrado', np.nan]

# %%
mi_df = pd.DataFrame(midic)
mi_df
# Out:
#      nombres edades  educacion
# 0   Carolina     30  Diplomado
# 1      Jairo     33   Posgrado
# 2  Jefferson     36        NaN

# %%
# se utlizo el comando insnull typo de datos boleanos nos imprime
mi_df['educacion'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# Name: educacion, dtype: bool

# %%
mi_df['nombres'][1]
# Out:
# 'Jairo'

# %%
mi_df['nombres'][1:3]
# Out:
# 1        Jairo
# 2    Jefferson
# Name: nombres, dtype: object

# %%
# comando iloc muestra la tabla
mi_df.iloc[1:3 , 0:2]
# Out:
#      nombres edades
# 1      Jairo     33
# 2  Jefferson     36

# %%
# columna uno fila dos
mi_df.iloc[1:2]
# Out:
#   nombres edades educacion
# 1   Jairo     33  Posgrado

# %%
#cuando se utliza corchetes y en separacion hay una coma al imprimir muestra en nombre
mi_df.iloc[1,0]
# Out:
# 'Jairo'

# %%
mi_df.iloc[1:2,0:2]
# Out:
#   nombres edades
# 1   Jairo     33

# %%
mi_df.iloc[1,1:3]
# Out:
# edades             33
# educacion    Posgrado
# Name: 1, dtype: object

# %%
#clase 3-10-2023
#importar datos con pandas-csv
datos = pd.read_csv('https://raw.githubusercontent.com/laboratoriolide/new-dimensions/main/Python/prueba2.csv')
datos
# Out:
#     Nombre  Edad  Peso_kg  Altura_m
# 0      Ana    33       60      1.60
# 1   Manuel    38       80      1.82
# 2  Daniela    29       70      1.54
# 3     Jose    25      100      1.70
# 4     Sara    40       95      1.75

# %%
# Un array, es un tipo de dato estructurado que permite almacenar un conjunto de datos homogeneo, es decir, 
#todos ellos del mismo tipo y relacionados
#importar datos con numpy con loadtxt sin poner el link solo el nombre del archivo
array = np.loadtxt('prueba.csv',delimiter=',')
array
# Out:
# array([[  11., 1000.,   19.,    8.,  101.,    5.,    6.,    5., 1000.],
#        [   9.,   17., 1000.,   13.,  101.,   20.,   15.,  101.,   19.],
#        [  14.,    4.,   17.,   13.,    4.,   20.,   19.,    4.,   17.],
#        [   8.,    8.,   16.,    9.,  101.,   20.,   12., 1000.,   19.],
#        [  13.,   11.,   20., 1000.,   14.,    9.,   12.,   16., 1000.],
#        [1000.,    5.,   20.,    5.,   14.,    8.,   11.,   15., 1000.],
#        [  19.,   14.,   17.,   12.,  101.,  101.,   19.,   18.,  101.],
#        [  13.,  101.,   14.,   13.,    7.,   14.,    4., 1000.,   14.],
#        [ 101.,    6.,   17., 1000., 1000.,    3.,   16.,   16.,    8.],
#        [  15.,   11.,   16.,   16.,   14.,   17.,   17.,   12.,    3.],
#        [  12.,   15.,   16.,    3.,    9.,   12.,   15.,    3.,   20.],
#        [  17.,   18.,    4.,    6.,    3.,   14.,   18.,   16.,   17.],
#        [1000.,    3.,   11., 1000.,    5.,   20.,   16.,    4.,    8.],
# ...

# %%
#Mostrar con un DataFrame la tabla que se creo con array
pd.DataFrame(array)
# Out:
#          0       1       2       3       4       5     6       7       8
# 0     11.0  1000.0    19.0     8.0   101.0     5.0   6.0     5.0  1000.0
# 1      9.0    17.0  1000.0    13.0   101.0    20.0  15.0   101.0    19.0
# 2     14.0     4.0    17.0    13.0     4.0    20.0  19.0     4.0    17.0
# 3      8.0     8.0    16.0     9.0   101.0    20.0  12.0  1000.0    19.0
# 4     13.0    11.0    20.0  1000.0    14.0     9.0  12.0    16.0  1000.0
# 5   1000.0     5.0    20.0     5.0    14.0     8.0  11.0    15.0  1000.0
# 6     19.0    14.0    17.0    12.0   101.0   101.0  19.0    18.0   101.0
# 7     13.0   101.0    14.0    13.0     7.0    14.0   4.0  1000.0    14.0
# 8    101.0     6.0    17.0  1000.0  1000.0     3.0  16.0    16.0     8.0
# 9     15.0    11.0    16.0    16.0    14.0    17.0  17.0    12.0     3.0
# 10    12.0    15.0    16.0     3.0     9.0    12.0  15.0     3.0    20.0
# 11    17.0    18.0     4.0     6.0     3.0    14.0  18.0    16.0    17.0
# ...

# %%
#importar los datos con el link y con indice de columnas
datos_pib = pd.read_csv('https://raw.githubusercontent.com/swcarpentry/python-novice-gapminder/main/episodes/data/gapminder_gdp_americas.csv')
                        #,index_col='country'
datos_pib
# Out:
#    continent              country  gdpPercap_1952  gdpPercap_1957  \
# 0   Americas            Argentina     5911.315053     6856.856212
# 1   Americas              Bolivia     2677.326347     2127.686326
# 2   Americas               Brazil     2108.944355     2487.365989
# 3   Americas               Canada    11367.161120    12489.950060
# 4   Americas                Chile     3939.978789     4315.622723
# 5   Americas             Colombia     2144.115096     2323.805581
# 6   Americas           Costa Rica     2627.009471     2990.010802
# 7   Americas                 Cuba     5586.538780     6092.174359
# 8   Americas   Dominican Republic     1397.717137     1544.402995
# 9   Americas              Ecuador     3522.110717     3780.546651
# 10  Americas          El Salvador     3048.302900     3421.523218
# 11  Americas            Guatemala     2428.237769     2617.155967
# 12  Americas                Haiti     1840.366939     1726.887882
# ...

# %%
# importa archivo csv con pandas - link
datos_pib = pd.read_csv('https://raw.githubusercontent.com/swcarpentry/python-novice-gapminder/main/episodes/data/gapminder_gdp_americas.csv')
datos_pib
# Out:
#    continent              country  gdpPercap_1952  gdpPercap_1957  \
# 0   Americas            Argentina     5911.315053     6856.856212
# 1   Americas              Bolivia     2677.326347     2127.686326
# 2   Americas               Brazil     2108.944355     2487.365989
# 3   Americas               Canada    11367.161120    12489.950060
# 4   Americas                Chile     3939.978789     4315.622723
# 5   Americas             Colombia     2144.115096     2323.805581
# 6   Americas           Costa Rica     2627.009471     2990.010802
# 7   Americas                 Cuba     5586.538780     6092.174359
# 8   Americas   Dominican Republic     1397.717137     1544.402995
# 9   Americas              Ecuador     3522.110717     3780.546651
# 10  Americas          El Salvador     3048.302900     3421.523218
# 11  Americas            Guatemala     2428.237769     2617.155967
# 12  Americas                Haiti     1840.366939     1726.887882
# ...

# %%
# utilizamos el comando loc para letras o caracteres
datos_pib.loc['Peru':'Venezuela']
# Out:
# Empty DataFrame
# Columns: [continent, country, gdpPercap_1952, gdpPercap_1957, gdpPercap_1962, gdpPercap_1967, gdpPercap_1972, gdpPercap_1977, gdpPercap_1982, gdpPercap_1987, gdpPercap_1992, gdpPercap_1997, gdpPercap_2002, gdpPercap_2007]
# Index: []

# %%
# iloc permite trabajar con numeros
datos_pib.iloc[19:25]
# Out:
#    continent              country  gdpPercap_1952  gdpPercap_1957  \
# 19  Americas                 Peru     3758.523437     4245.256698
# 20  Americas          Puerto Rico     3081.959785     3907.156189
# 21  Americas  Trinidad and Tobago     3023.271928     4100.393400
# 22  Americas        United States    13990.482080    14847.127120
# 23  Americas              Uruguay     5716.766744     6150.772969
# 24  Americas            Venezuela     7689.799761     9802.466526
#
#     gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# 19     4957.037982     5788.093330     5937.827283     6281.290855
# 20     5108.344630     6929.277714     9123.041742     9770.524921
# 21     4997.523971     5621.368472     6619.551419     7899.554209
# 22    16173.145860    19530.365570    21806.035940    24072.632130
# 23     5603.357717     5444.619620     5703.408898     6504.339663
# 24     8422.974165     9541.474188    10505.259660    13143.950950
#
# ...

# %%
datos_pib.loc['Peru':'Venezuela','continent']
# Out:
# Series([], Name: continent, dtype: object)

# %%
datos_pib.columns
# Out:
# Index(['continent', 'country', 'gdpPercap_1952', 'gdpPercap_1957',
#        'gdpPercap_1962', 'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977',
#        'gdpPercap_1982', 'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997',
#        'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
for col in datos_pib.columns:
    print(col)
# Out:
# continent
# country
# gdpPercap_1952
# gdpPercap_1957
# gdpPercap_1962
# gdpPercap_1967
# gdpPercap_1972
# gdpPercap_1977
# gdpPercap_1982
# gdpPercap_1987
# gdpPercap_1992
# gdpPercap_1997
# gdpPercap_2002
# gdpPercap_2007

# %%
# trabajar con bucles for para mostrar entradas y if
for col in datos_pib.columns:
        if '1967' in col:
         print(datos_pib[col])
# Out:
# 0      8052.953021
# 1      2586.886053
# 2      3429.864357
# 3     16076.588030
# 4      5106.654313
# 5      2678.729839
# 6      4161.727834
# 7      5690.268015
# 8      1653.723003
# 9      4579.074215
# 10     4358.595393
# 11     3242.531147
# 12     1452.057666
# 13     2538.269358
# 14     6124.703451
# 15     5754.733883
# 16     4643.393534
# 17     4421.009084
# 18     2299.376311
# 19     5788.093330
# 20     6929.277714
# 21     5621.368472
# 22    19530.365570
# 23     5444.619620
# 24     9541.474188
# Name: gdpPercap_1967, dtype: float64

# %%
datos_pib.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
datos_pib
# Out:
#    continent              country  gdpPercap_1952  gdpPercap_1957  \
# 0   Americas            Argentina     5911.315053     6856.856212
# 1   Americas              Bolivia     2677.326347     2127.686326
# 2   Americas               Brazil     2108.944355     2487.365989
# 3   Americas               Canada    11367.161120    12489.950060
# 4   Americas                Chile     3939.978789     4315.622723
# 5   Americas             Colombia     2144.115096     2323.805581
# 6   Americas           Costa Rica     2627.009471     2990.010802
# 7   Americas                 Cuba     5586.538780     6092.174359
# 8   Americas   Dominican Republic     1397.717137     1544.402995
# 9   Americas              Ecuador     3522.110717     3780.546651
# 10  Americas          El Salvador     3048.302900     3421.523218
# 11  Americas            Guatemala     2428.237769     2617.155967
# 12  Americas                Haiti     1840.366939     1726.887882
# ...

# %%
# head muestra el encabezado de las primeras filas,Devuelve las n primeras filas del DataFrame df
datos_pib.head()
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
# Canada     Americas    11367.161120    12489.950060    13462.485550
# Chile      Americas     3939.978789     4315.622723     4519.094331
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
# Canada       16076.588030    18970.570860    22090.883060    22898.792140
# Chile         5106.654313     5494.024437     4756.763836     5095.665738
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# ...

# %%
# comando  imprime los últimos N números o colas (tails) de una entrada. 
#Por lo general, muestra o imprime los últimos 10 números del archivo
datos_pib.tail()
# Out:
#    continent              country  gdpPercap_1952  gdpPercap_1957  \
# 20  Americas          Puerto Rico     3081.959785     3907.156189
# 21  Americas  Trinidad and Tobago     3023.271928     4100.393400
# 22  Americas        United States    13990.482080    14847.127120
# 23  Americas              Uruguay     5716.766744     6150.772969
# 24  Americas            Venezuela     7689.799761     9802.466526
#
#     gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# 20     5108.344630     6929.277714     9123.041742     9770.524921
# 21     4997.523971     5621.368472     6619.551419     7899.554209
# 22    16173.145860    19530.365570    21806.035940    24072.632130
# 23     5603.357717     5444.619620     5703.408898     6504.339663
# 24     8422.974165     9541.474188    10505.259660    13143.950950
#
#     gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# 20    10330.989150    12281.341910    14641.587110    16999.433300
# ...

# %%
datos_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   continent       25 non-null     object
#  1   country         25 non-null     object
#  2   gdpPercap_1952  25 non-null     float64
#  3   gdpPercap_1957  25 non-null     float64
#  4   gdpPercap_1962  25 non-null     float64
#  5   gdpPercap_1967  25 non-null     float64
#  6   gdpPercap_1972  25 non-null     float64
#  7   gdpPercap_1977  25 non-null     float64
#  8   gdpPercap_1982  25 non-null     float64
#  9   gdpPercap_1987  25 non-null     float64
#  10  gdpPercap_1992  25 non-null     float64
#  11  gdpPercap_1997  25 non-null     float64
#  12  gdpPercap_2002  25 non-null     float64
#  13  gdpPercap_2007  25 non-null     float64
# dtypes: float64(12), object(2)
# memory usage: 2.9+ KB

# %%
datos_pib['country']
# Out:
# 0               Argentina
# 1                 Bolivia
# 2                  Brazil
# 3                  Canada
# 4                   Chile
# 5                Colombia
# 6              Costa Rica
# 7                    Cuba
# 8      Dominican Republic
# 9                 Ecuador
# 10            El Salvador
# 11              Guatemala
# 12                  Haiti
# 13               Honduras
# 14                Jamaica
# 15                 Mexico
# 16              Nicaragua
# 17                 Panama
# 18               Paraguay
# 19                   Peru
# 20            Puerto Rico
# 21    Trinidad and Tobago
# 22          United States
# 23                Uruguay
# 24              Venezuela
# Name: country, dtype: object

# %%
datos_pib[datos_pib['country'] == 'Ecuador']
# Out:
#   continent  country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 9  Americas  Ecuador     3522.110717     3780.546651     4086.114078
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 9     4579.074215      5280.99471      6679.62326     7213.791267
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 9     6481.776993     7103.702595     7429.455877     5773.044512
#
#    gdpPercap_2007
# 9     6873.262326

# %%
datos_pib
# Out:
#    continent              country  gdpPercap_1952  gdpPercap_1957  \
# 0   Americas            Argentina     5911.315053     6856.856212
# 1   Americas              Bolivia     2677.326347     2127.686326
# 2   Americas               Brazil     2108.944355     2487.365989
# 3   Americas               Canada    11367.161120    12489.950060
# 4   Americas                Chile     3939.978789     4315.622723
# 5   Americas             Colombia     2144.115096     2323.805581
# 6   Americas           Costa Rica     2627.009471     2990.010802
# 7   Americas                 Cuba     5586.538780     6092.174359
# 8   Americas   Dominican Republic     1397.717137     1544.402995
# 9   Americas              Ecuador     3522.110717     3780.546651
# 10  Americas          El Salvador     3048.302900     3421.523218
# 11  Americas            Guatemala     2428.237769     2617.155967
# 12  Americas                Haiti     1840.366939     1726.887882
# ...

# %%
datos_pib[5:20]
# Out:
#    continent             country  gdpPercap_1952  gdpPercap_1957  \
# 5   Americas            Colombia     2144.115096     2323.805581
# 6   Americas          Costa Rica     2627.009471     2990.010802
# 7   Americas                Cuba     5586.538780     6092.174359
# 8   Americas  Dominican Republic     1397.717137     1544.402995
# 9   Americas             Ecuador     3522.110717     3780.546651
# 10  Americas         El Salvador     3048.302900     3421.523218
# 11  Americas           Guatemala     2428.237769     2617.155967
# 12  Americas               Haiti     1840.366939     1726.887882
# 13  Americas            Honduras     2194.926204     2220.487682
# 14  Americas             Jamaica     2898.530881     4756.525781
# 15  Americas              Mexico     3478.125529     4131.546641
# 16  Americas           Nicaragua     3112.363948     3457.415947
# 17  Americas              Panama     2480.380334     2961.800905
# ...

# %%
datos_pib[datos_pib['country'] == 'Argentina']
# Out:
#   continent    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0  Americas  Argentina     5911.315053     6856.856212     7133.166023
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     8052.953021     9443.038526     10079.02674     8997.897412
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     9139.671389      9308.41871     10967.28195     8797.640716
#
#    gdpPercap_2007
# 0     12779.37964

# %%
datos_pib[0:10]
# Out:
#   continent             country  gdpPercap_1952  gdpPercap_1957  \
# 0  Americas           Argentina     5911.315053     6856.856212
# 1  Americas             Bolivia     2677.326347     2127.686326
# 2  Americas              Brazil     2108.944355     2487.365989
# 3  Americas              Canada    11367.161120    12489.950060
# 4  Americas               Chile     3939.978789     4315.622723
# 5  Americas            Colombia     2144.115096     2323.805581
# 6  Americas          Costa Rica     2627.009471     2990.010802
# 7  Americas                Cuba     5586.538780     6092.174359
# 8  Americas  Dominican Republic     1397.717137     1544.402995
# 9  Americas             Ecuador     3522.110717     3780.546651
#
#    gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# 0     7133.166023     8052.953021     9443.038526    10079.026740
# 1     2180.972546     2586.886053     2980.331339     3548.097832
# ...

# %%
# CLASE 4-10-2023
import glob
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\IMPORTSOLUTION\\Desktop\\DEBERES_PYTHON\\PRACTICA EN CLASE'

# %%
glob.glob('python-novice-gapminder-data/data/*.csv')
# Out:
# []

# %%
glob('*/*/*all.csv')

# %%
#archivos_pib = glob('*/*/*gdp*.csv')
#archivos_pib

# %%
mi_lista = []
#for archivo in archivos_pib:
    #datos = pd.read_csv(archivo)
    #mi_lista.append(datos)

# %%
#pib_mundo = pd.concat(mi_lista)
#pib_mundo.head(n=3)
